# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
import pandas as pd

# %%
# %load_ext sql
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:poplpol@localhost:5430/food_ordering_system')

# %%
df = pd.read_csv (r'/Users/da_mac_41_/Downloads/diamonds.csv')

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.to_sql('diamonds', engine, if_exists='replace', index = False, chunksize=381109)#
# Out:
# 940

# %%
# %sql postgresql://postgres:polpol@localhost:5430/food_ordering_system

# %% [markdown]
# ## Show Distinct diamonds color

# %%
# %%sql
# SELECT color, COUNT(DISTINCT color) AS distinct_count
# FROM diamonds
# GROUP BY color
# ORDER BY distinct_count DESC
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 7 rows affected.
# [('D', 1), ('E', 1), ('F', 1), ('G', 1), ('H', 1), ('I', 1), ('J', 1)]

# %% [markdown]
# ## What is the most common color grade?

# %%
# %%sql
# SELECT color, COUNT(*) AS count
# FROM diamonds
# GROUP BY color
# ORDER BY count DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 1 rows affected.
# [('G', 11292)]

# %% [markdown]
# ## How does the color grade affects the average weight of the diamonds

# %%
# %%sql
# SELECT color, CAST(AVG(carat) AS decimal(10, 2))AS average_weight
# FROM diamonds
# GROUP BY color
# ORDER BY color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 7 rows affected.
# [('D', Decimal('0.66')),
#  ('E', Decimal('0.66')),
#  ('F', Decimal('0.74')),
#  ('G', Decimal('0.77')),
#  ('H', Decimal('0.91')),
#  ('I', Decimal('1.03')),
#  ('J', Decimal('1.16'))]

# %% [markdown]
# ## How does the average price vary with diamond color?

# %%
# %%sql
# SELECT color, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY color
# ORDER BY color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 7 rows affected.
# [('D', Decimal('3169.95')),
#  ('E', Decimal('3076.75')),
#  ('F', Decimal('3724.89')),
#  ('G', Decimal('3999.14')),
#  ('H', Decimal('4486.67')),
#  ('I', Decimal('5091.87')),
#  ('J', Decimal('5323.82'))]

# %%
# %%sql
# SELECT clarity, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY clarity;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 8 rows affected.
# [('VVS2', Decimal('3283.74')),
#  ('VS1', Decimal('3839.46')),
#  ('VS2', Decimal('3924.99')),
#  ('I1', Decimal('3924.17')),
#  ('VVS1', Decimal('2523.11')),
#  ('IF', Decimal('2864.84')),
#  ('SI1', Decimal('3996.00')),
#  ('SI2', Decimal('5063.03'))]

# %% [markdown]
# ## Are there any specific combinations of cut, color, and clarity that result in higher prices?

# %%
# %%sql
# SELECT cut, color, clarity, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY cut, color, clarity
# ORDER BY average_price DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 276 rows affected.
# [('Very Good', 'D', 'IF', Decimal('10298.26')),
#  ('Good', 'D', 'IF', Decimal('10030.33')),
#  ('Ideal', 'J', 'I1', Decimal('9454.00')),
#  ('Premium', 'D', 'IF', Decimal('9056.50')),
#  ('Premium', 'J', 'SI2', Decimal('7550.29')),
#  ('Fair', 'D', 'I1', Decimal('7383.00')),
#  ('Premium', 'J', 'VVS1', Decimal('7244.38')),
#  ('Ideal', 'I', 'SI2', Decimal('7191.91')),
#  ('Premium', 'I', 'VS2', Decimal('7156.35')),
#  ('Premium', 'I', 'SI2', Decimal('7148.48')),
#  ('Premium', 'J', 'IF', Decimal('7026.00')),
#  ('Good', 'I', 'SI2', Decimal('6933.01')),
#  ('Premium', 'H', 'SI2', Decimal('6718.95')),
#  ('Fair', 'I', 'SI2', Decimal('6658.02')),
#  ('Very Good', 'I', 'SI2', Decimal('6621.60')),
#  ('Ideal', 'D', 'IF', Decimal('6567.18')),
#  ('Ideal', 'J', 'SI2', Decimal('6555.17')),
#  ('Premium', 'J', 'VVS2', Decimal('6423.35')),
#  ('Premium', 'J', 'VS2', Decimal('6175.56')),
# ...

# %% [markdown]
# ## How does the average price vary for diamonds with different color grades across various cuts?

# %%
# %%sql
# SELECT cut, color, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY cut, color
# ORDER BY cut, color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 35 rows affected.
# [('Fair', 'D', Decimal('4291.06')),
#  ('Fair', 'E', Decimal('3682.31')),
#  ('Fair', 'F', Decimal('3827.00')),
#  ('Fair', 'G', Decimal('4239.25')),
#  ('Fair', 'H', Decimal('5135.68')),
#  ('Fair', 'I', Decimal('4685.45')),
#  ('Fair', 'J', Decimal('4975.66')),
#  ('Good', 'D', Decimal('3405.38')),
#  ('Good', 'E', Decimal('3423.64')),
#  ('Good', 'F', Decimal('3495.75')),
#  ('Good', 'G', Decimal('4123.48')),
#  ('Good', 'H', Decimal('4276.25')),
#  ('Good', 'I', Decimal('5078.53')),
#  ('Good', 'J', Decimal('4574.17')),
#  ('Ideal', 'D', Decimal('2629.09')),
#  ('Ideal', 'E', Decimal('2597.55')),
#  ('Ideal', 'F', Decimal('3374.94')),
#  ('Ideal', 'G', Decimal('3720.71')),
#  ('Ideal', 'H', Decimal('3889.33')),
#  ('Ideal', 'I', Decimal('4451.97')),
#  ('Ideal', 'J', Decimal('4918.19')),
#  ('Premium', 'D', Decimal('3631.29')),
#  ('Premium', 'E', Decimal('3538.91')),
# ...

# %% [markdown]
# ## How does the color of a diamond impact its clarity

# %%
# %%sql
# SELECT color, clarity, COUNT(*) AS count
# FROM diamonds
# GROUP BY color, clarity
# ORDER BY color, clarity;

# %% [markdown]
# ## How many diamonds are there in each cut category?

# %%
# %%sql
# SELECT cut, COUNT(*) AS diamond_count
# FROM diamonds
# GROUP BY cut;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('Good', 4906),
#  ('Very Good', 12082),
#  ('Premium', 13791),
#  ('Ideal', 21551),
#  ('Fair', 1610)]

# %% [markdown]
# ## How does the cut of diamonds affects its price

# %%
# %%sql
# SELECT cut, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY cut
# ORDER BY average_price DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('Premium', Decimal('4584.26')),
#  ('Fair', Decimal('4358.76')),
#  ('Very Good', Decimal('3981.76')),
#  ('Good', Decimal('3928.86')),
#  ('Ideal', Decimal('3457.54'))]

# %% [markdown]
# ## How does the cut of a diamond affect its average price per carat?

# %%
# %%sql
# SELECT cut, CAST(AVG(price/carat) AS decimal(10, 2)) AS avg_price_per_carat
# FROM diamonds
# GROUP BY cut
# ORDER BY avg_price_per_carat DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('Premium', Decimal('4222.91')),
#  ('Very Good', Decimal('4014.13')),
#  ('Ideal', Decimal('3919.70')),
#  ('Good', Decimal('3860.03')),
#  ('Fair', Decimal('3767.26'))]

# %% [markdown]
# ## Are there any specific cuts that consistently result in higher prices across different carat weights?

# %%
# %%sql
# SELECT cut, sum(price) AS average_price
# FROM diamonds
# GROUP BY cut
# HAVING COUNT(DISTINCT carat) > 1
# ORDER BY average_price DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('Ideal', Decimal('74513487')),
#  ('Premium', Decimal('63221498')),
#  ('Very Good', Decimal('48107623')),
#  ('Good', Decimal('19275009')),
#  ('Fair', Decimal('7017600'))]

# %% [markdown]
# ## What is the common clarity grade among diamonds with specific color grade

# %%
# %%sql
# SELECT color, clarity, COUNT(*) AS count
# FROM diamonds
# GROUP BY color, clarity
# HAVING COUNT(*) > 0
# ORDER BY color, count DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 56 rows affected.
# [('D', 'SI1', 2083),
#  ('D', 'VS2', 1697),
#  ('D', 'SI2', 1370),
#  ('D', 'VS1', 705),
#  ('D', 'VVS2', 553),
#  ('D', 'VVS1', 252),
#  ('D', 'IF', 73),
#  ('D', 'I1', 42),
#  ('E', 'VS2', 2470),
#  ('E', 'SI1', 2426),
#  ('E', 'SI2', 1713),
#  ('E', 'VS1', 1281),
#  ('E', 'VVS2', 991),
#  ('E', 'VVS1', 656),
#  ('E', 'IF', 158),
#  ('E', 'I1', 102),
#  ('F', 'VS2', 2201),
#  ('F', 'SI1', 2131),
#  ('F', 'SI2', 1609),
#  ('F', 'VS1', 1364),
#  ('F', 'VVS2', 975),
#  ('F', 'VVS1', 734),
#  ('F', 'IF', 385),
#  ('F', 'I1', 143),
#  ('G', 'VS2', 2347),
#  ('G', 'VS1', 2148),
#  ('G', 'SI1', 1976),
#  ('G', 'SI2', 1548),
#  ('G', 'VVS2', 1443),
#  ('G', 'VVS1', 999),
#  ('G', 'IF', 681),
#  ('G', 'I1', 150),
#  ('H', 'SI1', 2275),
#  ('H', 'VS2', 1643),
#  ('H', 'SI2', 1563),
#  ('H', 'VS1', 1169),
#  ('H', 'VVS2', 608),
#  ('H', 'VVS1', 585),
#  ('H', 'IF', 299),
#  ('H', 'I1', 162),
# ...

# %% [markdown]
# ## How does the average price differ for diamonds with different levels of clarity and cut?

# %%
# %%sql
# SELECT cut, clarity, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY cut, clarity
# ORDER BY average_price DESC;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 40 rows affected.
# [('Premium', 'SI2', Decimal('5545.94')),
#  ('Fair', 'SI2', Decimal('5173.92')),
#  ('Very Good', 'SI2', Decimal('4988.69')),
#  ('Ideal', 'SI2', Decimal('4755.95')),
#  ('Good', 'SI2', Decimal('4580.26')),
#  ('Premium', 'VS2', Decimal('4550.33')),
#  ('Premium', 'VS1', Decimal('4485.46')),
#  ('Premium', 'SI1', Decimal('4455.27')),
#  ('Very Good', 'IF', Decimal('4396.22')),
#  ('Ideal', 'I1', Decimal('4335.73')),
#  ('Good', 'VS2', Decimal('4262.24')),
#  ('Very Good', 'VS2', Decimal('4215.76')),
#  ('Fair', 'SI1', Decimal('4208.28')),
#  ('Fair', 'VS2', Decimal('4174.72')),
#  ('Fair', 'VS1', Decimal('4165.14')),
#  ('Good', 'IF', Decimal('4098.32')),
#  ('Very Good', 'I1', Decimal('4078.23')),
#  ('Premium', 'I1', Decimal('3947.33')),
#  ('Very Good', 'SI1', Decimal('3932.39')),
#  ('Fair', 'VVS1', Decimal('3871.35')),
#  ('Premium', 'IF', Decimal('3856.14')),
# ...

# %% [markdown]
# ## How does the carat weight of a diamond relate to its price?

# %%
# %%sql
# SELECT carat, COUNT(*) AS count, CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY carat
# ORDER BY carat;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 273 rows affected.
# [(0.2, 12, Decimal('365.17')),
#  (0.21, 9, Decimal('380.22')),
#  (0.22, 5, Decimal('391.40')),
#  (0.23, 293, Decimal('486.14')),
#  (0.24, 254, Decimal('505.19')),
#  (0.25, 212, Decimal('550.92')),
#  (0.26, 253, Decimal('550.90')),
#  (0.27, 233, Decimal('574.76')),
#  (0.28, 198, Decimal('580.12')),
#  (0.29, 130, Decimal('601.19')),
#  (0.3, 2604, Decimal('680.30')),
#  (0.31, 2249, Decimal('708.24')),
#  (0.32, 1840, Decimal('720.14')),
#  (0.33, 1189, Decimal('765.73')),
#  (0.34, 910, Decimal('756.38')),
#  (0.35, 667, Decimal('800.68')),
#  (0.36, 572, Decimal('781.38')),
#  (0.37, 394, Decimal('816.07')),
#  (0.38, 670, Decimal('904.44')),
#  (0.39, 398, Decimal('922.33')),
#  (0.4, 1299, Decimal('932.78')),
#  (0.41, 1382, Decimal('973.63')),
#  (0.42, 706, Decimal('994.44')),
#  (0.43, 488, Decimal('995.19')),
#  (0.44, 212, Decimal('1056.62')),
#  (0.45, 110, Decimal('1093.32')),
# ...

# %% [markdown]
# ## What is the average price per carat for diamonds with different levels of clarity?

# %%
# %%sql
# SELECT clarity, CAST(AVG(price / carat) AS decimal(10, 2)) AS average_price_per_carat
# FROM diamonds
# GROUP BY clarity;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 8 rows affected.
# [('VVS2', Decimal('4204.17')),
#  ('VS1', Decimal('4155.82')),
#  ('VS2', Decimal('4080.53')),
#  ('I1', Decimal('2796.30')),
#  ('VVS1', Decimal('3851.41')),
#  ('IF', Decimal('4259.93')),
#  ('SI1', Decimal('3849.08')),
#  ('SI2', Decimal('4010.85'))]

# %% [markdown]
# ## What is the average price per carat for diamonds of different color grades?

# %%
# %%sql
# SELECT color, CAST(AVG(price / carat) AS decimal(10, 2)) AS average_price_per_carat
# FROM diamonds
# GROUP BY color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 7 rows affected.
# [('J', Decimal('3825.65')),
#  ('E', Decimal('3804.61')),
#  ('D', Decimal('3952.56')),
#  ('I', Decimal('3996.40')),
#  ('H', Decimal('4008.03')),
#  ('G', Decimal('4163.41')),
#  ('F', Decimal('4134.73'))]

# %% [markdown]
# ## How does the depth percentage vary among different clarity grades

# %%
# %%sql
# SELECT clarity, MIN(depth) AS min_depth, MAX(depth) AS max_depth, CAST(AVG(depth)  AS decimal(10, 2)) AS average_depth
# FROM diamonds
# GROUP BY clarity;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 8 rows affected.
# [('VVS2', 51.0, 67.6, Decimal('61.66')),
#  ('VS1', 50.8, 71.8, Decimal('61.67')),
#  ('VS2', 43.0, 79.0, Decimal('61.72')),
#  ('I1', 55.6, 78.2, Decimal('62.73')),
#  ('VVS1', 54.0, 67.6, Decimal('61.62')),
#  ('IF', 52.3, 65.6, Decimal('61.51')),
#  ('SI1', 43.0, 72.9, Decimal('61.85')),
#  ('SI2', 53.1, 72.2, Decimal('61.77'))]

# %% [markdown]
# ## How does the depth percentage affect diamonds price

# %%
# %%sql
# SELECT
#   CASE
#     WHEN depth  <=43 THEN '43'
#     WHEN depth >= 50.0 AND depth < 59.9 THEN '50-59%'
#     WHEN depth >= 60.0 AND depth < 69.9 THEN '60-69'
#     WHEN depth >= 70.0 AND depth < 79.9 THEN '70-79'
#   END AS depth_range,
#   CAST(AVG(price) AS decimal(10, 2)) AS average_price
# FROM diamonds
# GROUP BY depth_range
# ORDER BY depth_range;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('43', Decimal('4206.00')),
#  ('50-59%', Decimal('4546.92')),
#  ('60-69', Decimal('3868.86')),
#  ('70-79', Decimal('4291.88')),
#  (None, Decimal('4483.45'))]

# %% [markdown]
# ## How does the depth percentage vary across different diamond cuts?

# %%
# %%sql
# SELECT cut, MIN(depth) AS min_depth, MAX(depth) AS max_depth, CAST(AVG(depth)AS decimal(10, 2))AS average_depth
# FROM diamonds
# GROUP BY cut;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('Good', 54.3, 67.0, Decimal('62.37')),
#  ('Very Good', 56.8, 64.9, Decimal('61.82')),
#  ('Premium', 58.0, 63.0, Decimal('61.26')),
#  ('Ideal', 43.0, 66.7, Decimal('61.71')),
#  ('Fair', 43.0, 79.0, Decimal('64.04'))]

# %% [markdown]
# ## How does the depth percentage impact the average price per carat for diamonds of different color grades?

# %%
# %%sql
# SELECT color, AVG(price / carat) AS average_price_per_carat, AVG(depth) AS average_depth_percentage
# FROM diamonds
# GROUP BY color
# ORDER BY color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 7 rows affected.
# [('D', 3952.564280175662, 61.69812546125477),
#  ('E', 3804.6114748198656, 61.6620904358481),
#  ('F', 4134.730683920377, 61.694581848668925),
#  ('G', 4163.411524474036, 61.757111229188524),
#  ('H', 4008.026940951264, 61.836849710982655),
#  ('I', 3996.402051410843, 61.84638509774959),
#  ('J', 3825.6491919432315, 61.887215099715085)]

# %% [markdown]
# ## How does the table percentage affect the diamond price

# %%
# %%sql
# SELECT
#   CASE
#     WHEN "table" >= 40 AND "table" <= 49.9 THEN '40-49.9'
#     WHEN "table" >= 50 AND "table" <= 59.9 THEN '50-59.9'
#     WHEN "table" >= 60 AND "table" < 69.9 THEN '60-69.9'
#     WHEN "table" >= 70 AND "table" < 79.9 THEN '70-79.9'
#   END AS table_range,
#   COUNT(*) AS table_count,
#   AVG(price) AS average_price
# FROM diamonds
# GROUP BY table_range
# ORDER BY table_range;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 5 rows affected.
# [('40-49.9', 4, Decimal('2513.0000000000000000')),
#  ('50-59.9', 44849, Decimal('3798.1424112020334902')),
#  ('60-69.9', 9070, Decimal('4600.2592061742006615')),
#  ('70-79.9', 16, Decimal('2783.6250000000000000')),
#  (None, 1, Decimal('13387.0000000000000000'))]

# %% [markdown]
# ## How does the table percentage impact the average price per carat for diamonds of different color grades?

# %%
# %%sql
# SELECT
#   CASE
#     WHEN "table" >= 10 AND "table" <= 19.9 THEN '40-49.9'
#     WHEN "table" >= 20 AND "table" <= 29.9 THEN '30-39.9'
#     WHEN "table" >= 30 AND "table" <= 39.9 THEN '40-49.9'
#     WHEN "table" >= 40 AND "table" <= 49.9 THEN '40-49.9'
#     WHEN "table" >= 50 AND "table" <= 59.9 THEN '50-59.9'
#     WHEN "table" >= 60 AND "table" < 69.9 THEN '60-69.9'
#     WHEN "table" >= 70 AND "table" < 79.9 THEN '70-79.9'
#   END AS table_range,
#   color,
#   AVG(price / carat) AS avg_price_per_carat
# FROM diamonds
# GROUP BY table_range, color
# ORDER BY table_range, color;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 23 rows affected.
# [('40-49.9', 'E', 1867.2413793103449),
#  ('40-49.9', 'I', 4377.903846153846),
#  ('50-59.9', 'D', 3903.329162094154),
#  ('50-59.9', 'E', 3780.711977945886),
#  ('50-59.9', 'F', 4111.013026763808),
#  ('50-59.9', 'G', 4152.3905506931105),
#  ('50-59.9', 'H', 3953.669040965956),
#  ('50-59.9', 'I', 3888.1066558824436),
#  ('50-59.9', 'J', 3804.5177444700503),
#  ('60-69.9', 'D', 4199.549058278983),
#  ('60-69.9', 'E', 3915.9391408908527),
#  ('60-69.9', 'F', 4258.63038798602),
#  ('60-69.9', 'G', 4230.004669123519),
#  ('60-69.9', 'H', 4262.991284684981),
#  ('60-69.9', 'I', 4485.0029637486),
#  ('60-69.9', 'J', 3906.1223754712246),
#  ('70-79.9', 'D', 3335.211267605634),
#  ('70-79.9', 'E', 5889.439293598233),
#  ('70-79.9', 'F', 3293.3122892731276),
#  ('70-79.9', 'G', 3025.1848440908675),
#  ('70-79.9', 'H', 2738.0920390765646),
#  ('70-79.9', 'I', 2143.283582089552),
# ...

# %% [markdown]
# ## Do diamonds with a specific table percentage range tend to have more or fewer inclusions or flaws?

# %%
# %%sql
# SELECT
#   CASE
#     WHEN "table" >= 10 AND "table" <= 19.9 THEN '40-49.9'
#     WHEN "table" >= 20 AND "table" <= 29.9 THEN '30-39.9'
#     WHEN "table" >= 30 AND "table" <= 39.9 THEN '40-49.9'
#     WHEN "table" >= 40 AND "table" <= 49.9 THEN '40-49.9'
#     WHEN "table" >= 50 AND "table" <= 59.9 THEN '50-59.9'
#     WHEN "table" >= 60 AND "table" < 69.9 THEN '60-69.9'
#     WHEN "table" >= 70 AND "table" < 79.9 THEN '70-79.9'
#   END AS table_range,
#   clarity,
#   COUNT(*) AS inclusion_count
# FROM diamonds
# GROUP BY table_range, clarity
# ORDER BY table_range, clarity;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# 23 rows affected.
# [('40-49.9', 'SI1', 1),
#  ('40-49.9', 'VS1', 3),
#  ('50-59.9', 'I1', 523),
#  ('50-59.9', 'IF', 1639),
#  ('50-59.9', 'SI1', 10552),
#  ('50-59.9', 'SI2', 7088),
#  ('50-59.9', 'VS1', 6940),
#  ('50-59.9', 'VS2', 10345),
#  ('50-59.9', 'VVS1', 3285),
#  ('50-59.9', 'VVS2', 4477),
#  ('60-69.9', 'I1', 218),
#  ('60-69.9', 'IF', 151),
#  ('60-69.9', 'SI1', 2506),
#  ('60-69.9', 'SI2', 2104),
#  ('60-69.9', 'VS1', 1225),
#  ('60-69.9', 'VS2', 1907),
#  ('60-69.9', 'VVS1', 370),
#  ('60-69.9', 'VVS2', 589),
#  ('70-79.9', 'SI1', 5),
#  ('70-79.9', 'SI2', 2),
#  ('70-79.9', 'VS1', 3),
#  ('70-79.9', 'VS2', 6),
#  (None, 'SI1', 1)]

# %%
# %%sql
# SELECT
#   cut,
#   CASE
#     WHEN "table" >= 10 AND "table" <= 19.9 THEN '40-49.9'
#     WHEN "table" >= 20 AND "table" <= 29.9 THEN '30-39.9'
#     WHEN "table" >= 30 AND "table" <= 39.9 THEN '40-49.9'
#     WHEN "table" >= 40 AND "table" <= 49.9 THEN '40-49.9'
#     WHEN "table" >= 50 AND "table" <= 59.9 THEN '50-59.9'
#     WHEN "table" >= 60 AND "table" < 69.9 THEN '60-69.9'
#     WHEN "table" >= 70 AND "table" < 79.9 THEN '70-79.9'
#   END AS table_range,
#   AVG("price") AS avg_table_percentage,
#
#  FROM diamonds
#  GROUP BY cut, table_range
#  ORDER BY cut, table_range;
# Out:
#  * postgresql://postgres:***@localhost:5430/food_ordering_system
# (psycopg2.errors.SyntaxError) syntax error at or near "FROM"
# LINE 14:  FROM diamonds
#           ^
#
# [SQL: SELECT
#   cut,
#   CASE
#     WHEN "table" >= 10 AND "table" <= 19.9 THEN '40-49.9'
#     WHEN "table" >= 20 AND "table" <= 29.9 THEN '30-39.9'
#     WHEN "table" >= 30 AND "table" <= 39.9 THEN '40-49.9'
#     WHEN "table" >= 40 AND "table" <= 49.9 THEN '40-49.9'
#     WHEN "table" >= 50 AND "table" <= 59.9 THEN '50-59.9'
#     WHEN "table" >= 60 AND "table" < 69.9 THEN '60-69.9'
#     WHEN "table" >= 70 AND "table" < 79.9 THEN '70-79.9'
#   END AS table_range,
#   AVG("price") AS avg_table_percentage,
#
#  FROM diamonds
#  GROUP BY cut, table_range
#  ORDER BY cut, table_range;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
